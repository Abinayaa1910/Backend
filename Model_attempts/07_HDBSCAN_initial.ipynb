# %%
import pandas as pd

# Load the dataset
df = pd.read_excel('sample_customer_database_5000_singapore.xlsx')

# %%
# First look at the data
print(df.head())  # First 5 rows
# Out:
#   Customer ID        Full Name                Email Address  Phone Number  \
# 0       C0001     Norma Fisher          ysullivan@yahoo.com      82421948
# 1       C0002      Levi Durham            qgrimes@gmail.com      97535139
# 2       C0003   Kimberly Olsen  sean96@johnston-roberts.com      71122018
# 3       C0004   Matthew Davies    nguyendarrell@hotmail.com      41352560
# 4       C0005  Angela Martinez    myersmitchell@johnson.com        869141
#
#   Date Joined     Location  Gender Loyalty Tier  \
# 0  2023-08-11     Tampines  Female     Platinum
# 1  2022-11-24      Geylang  Female     Platinum
# 2  2023-06-19     Tampines  Female     Platinum
# 3  2025-04-04   Ang Mo Kio    Male       Silver
# 4  2025-01-15  Bukit Batok  Female     Platinum
#
#                                                Notes
# 0                        Together range line beyond.
# 1  Language ball floor meet usually board necessary.
# 2                 Support time operation wear often.
# ...

# %%
import numpy
import pandas

print("NumPy version:", numpy.__version__)
print("Pandas version:", pandas.__version__)
# Out:
# NumPy version: 1.26.4
# Pandas version: 2.2.3

# %%
# Shape of the dataset
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (5000, 9)

# %%
# Columns and Data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID    5000 non-null   object
#  1   Full Name      5000 non-null   object
#  2   Email Address  5000 non-null   object
#  3   Phone Number   5000 non-null   int64
#  4   Date Joined    5000 non-null   datetime64[ns]
#  5   Location       5000 non-null   object
#  6   Gender         5000 non-null   object
#  7   Loyalty Tier   5000 non-null   object
#  8   Notes          5000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 351.7+ KB
# None

# %%
# Check for missing values
print("Missing values per column:\n", df.isnull().sum())
# Out:
# Missing values per column:
#  Customer ID      0
# Full Name        0
# Email Address    0
# Phone Number     0
# Date Joined      0
# Location         0
# Gender           0
# Loyalty Tier     0
# Notes            0
# dtype: int64

# %%
# Check for duplicate rows
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Unique values per column
print("Unique values per column:\n", df.nunique())
# Out:
# Unique values per column:
#  Customer ID      5000
# Full Name        4835
# Email Address    4983
# Phone Number     4998
# Date Joined      1084
# Location           27
# Gender              2
# Loyalty Tier        3
# Notes            5000
# dtype: int64

# %%
df['Location'].unique()
# Out:
# array(['Tampines', 'Geylang', 'Ang Mo Kio', 'Bukit Batok', 'Bedok',
#        'Woodlands', 'Pasir Ris', 'Yishun', 'Bukit Timah', 'Central Area',
#        'Clementi', 'Punggol', 'Queenstown', 'Bukit Panjang', 'Sembawang',
#        'Marine Parade', 'Bishan', 'Sengkang', 'Toa Payoh', 'Jurong West',
#        'Jurong East', 'Choa Chu Kang', 'Novena', 'Kallang', 'Hougang',
#        'Bukit Merah', 'Serangoon'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Gender', palette='pastel')
plt.title('Gender Distribution')
plt.ylabel('Count')
plt.xlabel('Gender')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_892\713506157.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Gender', palette='pastel')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Loyalty Tier', palette='muted')
plt.title('Loyalty Tier Distribution')
plt.ylabel('Count')
plt.xlabel('Loyalty Tier')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_892\3928779869.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Loyalty Tier', palette='muted')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Tenure', palette='cool')
plt.title('Tenure Category Distribution')
plt.ylabel('Count')
plt.xlabel('Tenure Category')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 plt.figure(figsize=(6, 4))
# ----> 2 sns.countplot(data=df, x='Tenure', palette='cool')
#       3 plt.title('Tenure Category Distribution')
#       4 plt.ylabel('Count')
#
# File c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
# ...

# %%
pd.crosstab(df['Gender'], df['Loyalty Tier']).plot(kind='bar', stacked=True, figsize=(8,5), colormap='Set2')
plt.title('Gender vs Loyalty Tier')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
zone_map = {
    # 🟦 East Region
    'Tampines': 'East',
    'Pasir Ris': 'East',
    'Bedok': 'East',
    'Geylang': 'East',
    'Marine Parade': 'East',

    # 🟩 North Region
    'Woodlands': 'North',
    'Yishun': 'North',
    'Sembawang': 'North',

    # 🟫 West Region
    'Bukit Batok': 'West',
    'Bukit Panjang': 'West',
    'Jurong West': 'West',
    'Jurong East': 'West',
    'Choa Chu Kang': 'West',
    'Clementi': 'West',

    # 🟪 North-East Region
    'Ang Mo Kio': 'North-East',
    'Hougang': 'North-East',
    'Punggol': 'North-East',
    'Sengkang': 'North-East',
    'Serangoon': 'North-East',

    # 🟥 Central Region
    'Queenstown': 'Central',
    'Bukit Timah': 'Central',
    'Central Area': 'Central',
    'Toa Payoh': 'Central',
    'Bishan': 'Central',
    'Novena': 'Central',
    'Bukit Merah': 'Central',
    'Kallang': 'Central'
}

# %%
# Count and percentage distribution of Location_Zone
zone_counts = df['Location_Zone'].value_counts()
zone_percentages = df['Location_Zone'].value_counts(normalize=True) * 100

# Combine into one DataFrame
location_zone_eda = pd.DataFrame({
    'Count': zone_counts,
    'Percentage (%)': zone_percentages.round(2)
})
display(location_zone_eda)
# Out:
#                Count  Percentage (%)
# Location_Zone
# Central         1502           30.04
# West            1135           22.70
# North-East       921           18.42
# East             876           17.52
# North            566           11.32

# %%
plt.figure(figsize=(6, 6))
plt.pie(zone_counts, labels=zone_counts.index, autopct='%1.1f%%', colors=sns.color_palette('Set2'))
plt.title("Customer Distribution by Location Zone")
plt.tight_layout()
plt.show()

# %%
# Apply zone mapping
df['Location_Zone'] = df['Location'].map(zone_map).fillna('Unknown')

# %%
# Ensure 'Date_Joined' is in datetime format
df['Date Joined'] = pd.to_datetime(df['Date Joined'], errors='coerce')

# Today's date
today = pd.to_datetime("today")

# Feature Engineering from Date_Joined
df['Days_Since_Joined'] = (today - df['Date Joined']).dt.days
df['Join_Year'] = df['Date Joined'].dt.year
df['Join_Month'] = df['Date Joined'].dt.month
df['Join_Quarter'] = df['Date Joined'].dt.quarter
df['Is_New'] = (df['Days_Since_Joined'] <= 180).astype(int)

# Display engineered features
df[['Date Joined', 'Days_Since_Joined', 'Join_Year', 'Join_Month', 'Join_Quarter', 'Is_New']].head()
# Out:
#   Date Joined  Days_Since_Joined  Join_Year  Join_Month  Join_Quarter  Is_New
# 0  2023-08-11                650       2023           8             3       0
# 1  2022-11-24                910       2022          11             4       0
# 2  2023-06-19                703       2023           6             2       0
# 3  2025-04-04                 48       2025           4             2       1
# 4  2025-01-15                127       2025           1             1       1

# %%
# Save for reuse
categorical_cols = [
    'Location',
    'Gender',
    'Loyalty Tier',
    'Join_Year',
    'Join_Month',
    'Join_Quarter',
    'Is_New'
]

numerical_cols = [
    'Days_Since_Joined'
]

# %%
#CAT ONLY

from sklearn.preprocessing import OneHotEncoder
import umap
import hdbscan
import numpy as np
from sklearn.metrics import silhouette_score

# Step 0: Define categorical columns
categorical_cols = [
    'Location_Zone', 'Gender', 'Loyalty Tier',
    'Join_Year', 'Join_Month', 'Join_Quarter', 'Is_New'
]

# Step 1: One-Hot Encode categorical features
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
cat_encoded = encoder.fit_transform(df[categorical_cols])

# Step 2: UMAP for dimensionality reduction
cat_embed = umap.UMAP(
    n_neighbors=70,      # try 15, 30, 50
    min_dist=0.1,        # try 0.05, 0.3
    n_components=10,     # dimensionality of embedding
    random_state=42
).fit_transform(cat_encoded)

# Step 3: HDBSCAN Clustering
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=50,   # try 10, 15, 20
    min_samples=15,         # try 3, 5, 10
    prediction_data=True
)
df['HDBSCAN_Cat_Label'] = clusterer.fit_predict(cat_embed)

# Step 4: Evaluation
mask = df['HDBSCAN_Cat_Label'] != -1
if mask.sum() > 1:
    silhouette = silhouette_score(cat_embed[mask], df.loc[mask, 'HDBSCAN_Cat_Label'])
    print("✅ UMAP + HDBSCAN (Categorical) Silhouette Score:", silhouette)
else:
    print("⚠️ Too much noise – Silhouette Score not computed")

# Step 5: Show cluster count
n_clusters = len(np.unique(df['HDBSCAN_Cat_Label'])) - (1 if -1 in df['HDBSCAN_Cat_Label'] else 0)
print(f"📊 Number of clusters (excluding noise): {n_clusters}")

# Optional: Preview first few labels
print(df[['HDBSCAN_Cat_Label']].head())
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
df_clean = df[df['HDBSCAN_CatNum_Label'] != -1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HDBSCAN_CatNum_Label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ...

# %%
cluster_profiles = df_clean.groupby('HDBSCAN_CatNum_Label').agg({
    'Days_Since_Joined': ['mean', 'min', 'max'],
    'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
    'Loyalty Tier': lambda x: x.value_counts(normalize=True).to_dict(),
    'Location_Zone': lambda x: x.value_counts().head(3).to_dict(),
    'Is_New': 'mean'
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 cluster_profiles = df_clean.groupby('HDBSCAN_CatNum_Label').agg({
#       2     'Days_Since_Joined': ['mean', 'min', 'max'],
#       3     'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
#       4     'Loyalty Tier': lambda x: x.value_counts(normalize=True).to_dict(),
#       5     'Location_Zone': lambda x: x.value_counts().head(3).to_dict(),
#       6     'Is_New': 'mean'
#       7 })
#
# NameError: name 'df_clean' is not defined

# %%
cluster_profiles.columns = ['_'.join(col).strip() for col in cluster_profiles.columns.values]
cluster_profiles.reset_index(inplace=True)

# %%
cluster_profiles.to_csv("cluster_profiles.csv", index=False)

# %%
import umap
import matplotlib.pyplot as plt
import seaborn as sns

# Recreate UMAP 2D projection using categorical + numerical combined features
umap_2d = umap.UMAP(n_components=2, random_state=42).fit_transform(combined_features)
df['UMAP1'] = umap_2d[:, 0]
df['UMAP2'] = umap_2d[:, 1]

# 1. 📌 UMAP 2D Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df[df['HDBSCAN_CatNum_Label'] != -1], x='UMAP1', y='UMAP2',
                hue='HDBSCAN_CatNum_Label', palette='tab20', legend='full', s=50)
plt.title("📌 UMAP 2D Cluster Visualization (Cat + Num)")
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# 2. 📊 Bar Chart — Cluster Sizes
plt.figure(figsize=(10, 4))
cluster_counts = df['HDBSCAN_CatNum_Label'].value_counts().sort_index()
sns.barplot(x=cluster_counts.index, y=cluster_counts.values, palette='viridis')
plt.title("📊 Cluster Sizes (Cat + Num)")
plt.xlabel("Cluster Label")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. 📦 Boxplot — Days_Since_Joined by Cluster
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[df['HDBSCAN_CatNum_Label'] != -1], x='HDBSCAN_CatNum_Label', y='Days_Since_Joined', palette='Set3')
plt.title("📦 Tenure Distribution (Days_Since_Joined) by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Days Since Joined")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 6
#       3 import seaborn as sns
#       5 # Recreate UMAP 2D projection using categorical + numerical combined features
# ----> 6 umap_2d = umap.UMAP(n_components=2, random_state=42).fit_transform(combined_features)
#       7 df['UMAP1'] = umap_2d[:, 0]
#       8 df['UMAP2'] = umap_2d[:, 1]
#
# NameError: name 'combined_features' is not defined

# %%
# Loyalty Tier by Cluster (Stacked % Bar)
import pandas as pd
import matplotlib.pyplot as plt

loyalty_dist = pd.crosstab(df['HDBSCAN_CatNum_Label'], df['Loyalty Tier'], normalize='index') * 100
loyalty_dist.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='Paired')

plt.title("🎖️ Loyalty Tier Distribution by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Percentage (%)")
plt.legend(title="Loyalty Tier", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_46088\2114913009.py:12: UserWarning: Glyph 127894 (\N{MILITARY MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127894 (\N{MILITARY MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Gender Distribution per Cluster
gender_dist = pd.crosstab(df['HDBSCAN_CatNum_Label'], df['Gender'], normalize='index') * 100
gender_dist.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='coolwarm')

plt.title("👥 Gender Distribution by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Percentage (%)")
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_46088\846555803.py:9: UserWarning: Glyph 128101 (\N{BUSTS IN SILHOUETTE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128101 (\N{BUSTS IN SILHOUETTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Mean Tenure per Cluster (Days_Since_Joined)
tenure_avg = df.groupby('HDBSCAN_CatNum_Label')['Days_Since_Joined'].mean()

tenure_avg.plot(kind='line', marker='o', figsize=(10, 4))
plt.title("📈 Average Tenure (Days_Since_Joined) by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Avg Days Since Joined")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_46088\4009135173.py:9: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cluster_profiles = df[df['HDBSCAN_CatNum_Label'] != -1].groupby('HDBSCAN_CatNum_Label').agg({
#       2     'Days_Since_Joined': ['mean', 'min', 'max'],
#       3     'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
#       4     'Loyalty Tier': lambda x: x.value_counts(normalize=True).to_dict(),
#       5     'Location_Zone': lambda x: x.value_counts().head(3).to_dict(),
#       6     'Is_New': 'mean'
#       7 })
#       8 cluster_profiles.columns = ['_'.join(col).strip() for col in cluster_profiles.columns.values]
#       9 cluster_profiles.reset_index(inplace=True)
#
# NameError: name 'df' is not defined

# %%
def summarize_clusters(df, label_col, title):
    cluster_ids = sorted(df[label_col].dropna().unique())
    for cid in cluster_ids:
        if cid == -1:
            continue  # skip noise
        print(f"\n🧩 {title} {cid} — Sample Records:")
        display(df[df[label_col] == cid][[
            'Location', 'Gender', 'Loyalty Tier',
            'Join_Year', 'Join_Month', 'Join_Quarter', 'Is_New',
            'Days_Since_Joined'
        ]].head(3))

# 📦 Print Categorical-Only Clusters
if 'HDBSCAN_Cat_Label' in df.columns:
    summarize_clusters(df, 'HDBSCAN_Cat_Label', "Cat_Only Cluster")
else:
    print("⚠️ HDBSCAN_Cat_Label not found. Please run the categorical-only model first.")

# 📦 Print Cat + Num Clusters
if 'HDBSCAN_CatNum_Label' in df.columns:
    summarize_clusters(df, 'HDBSCAN_CatNum_Label', "Cat+Num Cluster")
else:
    print("⚠️ HDBSCAN_CatNum_Label not found. Please run the cat+num model first.")
# Out:
# ⚠️ HDBSCAN_Cat_Label not found. Please run the categorical-only model first.
#
# 🧩 Cat+Num Cluster 0 — Sample Records:
#        Location Gender Loyalty Tier  Join_Year  Join_Month  Join_Quarter  \
# 15   Queenstown   Male     Platinum       2022           6             2
# 17    Sembawang   Male       Silver       2022           5             2
# 32  Bukit Timah   Male       Silver       2022           5             2
#
#     Is_New  Days_Since_Joined
# 15       0               1070
# 17       0               1086
# 32       0               1087
# 🧩 Cat+Num Cluster 1 — Sample Records:
#          Location  Gender Loyalty Tier  Join_Year  Join_Month  Join_Quarter  \
# 28        Punggol  Female       Silver       2024          10             4
# 30   Central Area    Male       Silver       2024          12             4
# 37  Marine Parade    Male     Platinum       2024          12             4
#
#     Is_New  Days_Since_Joined
# 28       0                225
# ...

# %%
#current at use 
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import umap
import hdbscan
import numpy as np
from sklearn.metrics import silhouette_score

# Step 0: Define columns
categorical_cols = [
    'Location_Zone', 'Gender', 'Loyalty Tier',
    'Join_Year', 'Join_Month', 'Join_Quarter', 'Is_New'
]
numerical_cols = ['Days_Since_Joined']

# Step 1: Encode categorical
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
cat_encoded = encoder.fit_transform(df[categorical_cols])

# Step 2: Scale numerical
scaler = StandardScaler()
num_scaled = scaler.fit_transform(df[numerical_cols])

# Step 3: Combine features
combined_features = np.hstack([cat_encoded, num_scaled])

# Step 4: UMAP
embed = umap.UMAP(
    n_neighbors=70,
    min_dist=0.1,
    n_components=10,
    random_state=42
).fit_transform(combined_features)

# Step 5: HDBSCAN
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=150,
    min_samples=15,
    prediction_data=True
)
df['HDBSCAN_CatNum_Label'] = clusterer.fit_predict(embed)

# Step 6: Evaluation
mask = df['HDBSCAN_CatNum_Label'] != -1
if mask.sum() > 1:
    silhouette = silhouette_score(embed[mask], df.loc[mask, 'HDBSCAN_CatNum_Label'])
    print("✅ UMAP + HDBSCAN (Cat + Num) Silhouette Score:", silhouette)
else:
    print("⚠️ Too much noise – Silhouette Score not computed")

# Step 7: Cluster count
n_clusters = len(np.unique(df['HDBSCAN_CatNum_Label'])) - (1 if -1 in df['HDBSCAN_CatNum_Label'] else 0)
print(f"📊 Number of clusters (excluding noise): {n_clusters}")

# Optional: Preview
print(df[['HDBSCAN_CatNum_Label']].head())
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
#to test with tenure cat 
def categorize_tenure(days):
    if days <= 90:
        return 'Very New'
    elif days <= 270:
        return 'New'
    elif days <= 540:
        return 'Mid-Term'
    elif days <= 900:
        return 'Established'
    else:
        return 'Loyal'

df['Tenure_Category'] = df['Days_Since_Joined'].apply(categorize_tenure)

# Optional: Make it an ordered category
from pandas.api.types import CategoricalDtype
tenure_order = CategoricalDtype(['Very New', 'New', 'Mid-Term', 'Established', 'Loyal'], ordered=True)
df['Tenure_Category'] = df['Tenure_Category'].astype(tenure_order)

# Preview
print(df[['Days_Since_Joined', 'Tenure_Category']].head())
# Out:
#    Days_Since_Joined Tenure_Category
# 0                650     Established
# 1                910           Loyal
# 2                703     Established
# 3                 48        Very New
# 4                127             New

# %%
#current at test 
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import umap
import hdbscan
import numpy as np
from sklearn.metrics import silhouette_score

# Step 0: Define columns
categorical_cols = [
    'Location_Zone', 'Gender', 'Loyalty Tier',
    'Join_Year', 'Join_Month', 'Join_Quarter', 'Tenure_Category'
]

# Step 1: Encode categorical
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
cat_encoded = encoder.fit_transform(df[categorical_cols])

# Step 2: Scale numerical
scaler = StandardScaler()
num_scaled = scaler.fit_transform(df[numerical_cols])

# Step 3: Combine features
combined_features = np.hstack([cat_encoded, num_scaled])

# Step 4: UMAP
embed = umap.UMAP(
    n_neighbors=150,
    min_dist=0.1,
    n_components=10,
    random_state=42
).fit_transform(combined_features)

# Step 5: HDBSCAN
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=400,
    min_samples=15,
    prediction_data=True
)
df['HDBSCAN_CatNum_Label'] = clusterer.fit_predict(embed)

# Step 6: Evaluation
mask = df['HDBSCAN_CatNum_Label'] != -1
if mask.sum() > 1:
    silhouette = silhouette_score(embed[mask], df.loc[mask, 'HDBSCAN_CatNum_Label'])
    print("✅ UMAP + HDBSCAN (Cat + Num) Silhouette Score:", silhouette)
else:
    print("⚠️ Too much noise – Silhouette Score not computed")

# Step 7: Cluster count
n_clusters = len(np.unique(df['HDBSCAN_CatNum_Label'])) - (1 if -1 in df['HDBSCAN_CatNum_Label'] else 0)
print(f"📊 Number of clusters (excluding noise): {n_clusters}")

# Optional: Preview
print(df[['HDBSCAN_CatNum_Label']].head())
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
# Step 1: Filter out noise
df_clean = df[df['HDBSCAN_CatNum_Label'] != -1]

# Step 2: Group and aggregate
cluster_profiles = df_clean.groupby('HDBSCAN_CatNum_Label').agg({
    'Days_Since_Joined': ['mean', 'min', 'max'],
    'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
    'Loyalty Tier': lambda x: x.value_counts(normalize=True).to_dict(),
    'Location_Zone': lambda x: x.value_counts().head(3).to_dict(),  # or use 'Location'
    'Tenure_Category': lambda x: x.value_counts(normalize=True).to_dict(),
    'Is_New': 'mean'
})

# Step 3: Flatten columns for readability
cluster_profiles.columns = ['_'.join(col).strip() for col in cluster_profiles.columns.values]
cluster_profiles.reset_index(inplace=True)

#
cluster_profiles
# Out:
#    HDBSCAN_CatNum_Label  Days_Since_Joined_mean  Days_Since_Joined_min  \
# 0                     0              460.813483                    417
# 1                     1               87.756410                     36
# 2                     2              369.805897                    326
# 3                     3              230.668758                    142
# 4                     4              556.398148                    509
# 5                     5              645.392593                    600
# 6                     6             1004.974874                    873
# 7                     7              827.796729                    783
# 8                     8              738.599057                    692
#
#    Days_Since_Joined_max                                    Gender_<lambda>  \
# 0                    507  {'Male': 0.5438202247191011, 'Female': 0.45617...
# 1                    141  {'Female': 0.5470085470085471, 'Male': 0.45299...
# ...

# %%
#trying with pca
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import umap
import hdbscan

# Step 0: Ordinal Encoding and Tenure Binning
df['Loyalty_Tier_Score'] = df['Loyalty Tier'].map({'Silver': 1, 'Gold': 2, 'Platinum': 3})
df['Tenure'] = pd.cut(
    df['Days_Since_Joined'],
    bins=[0, 300, 700, df['Days_Since_Joined'].max()],
    labels=['New', 'Mid-Term', 'Loyal']
)

# Step 1: One-Hot Encode categorical features
categorical_cols = ['Location_Zone', 'Gender', 'Join_Year', 'Join_Month', 'Join_Quarter', 'Tenure']
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
cat_encoded = encoder.fit_transform(df[categorical_cols])

# Step 2: Scale numerical feature (ordinal Loyalty Tier)
scaler = StandardScaler()
num_scaled = scaler.fit_transform(df[['Loyalty_Tier_Score']])

# Step 3: Combine encoded + scaled features
combined_features = np.hstack([cat_encoded, num_scaled])

# ✅ Step 4: PCA for variance reduction
pca = PCA(n_components=0.95, random_state=42)
pca_features = pca.fit_transform(combined_features)

# ✅ Step 5: UMAP for 10D embedding
umap_embed = umap.UMAP(
    n_neighbors=250,
    min_dist=0.1,
    n_components=10,
    random_state=42
).fit_transform(pca_features)

# ✅ Step 6: HDBSCAN Clustering
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=250,
    min_samples=20,
    prediction_data=True
)
df['HDBSCAN_CatNum_Label_PCA'] = clusterer.fit_predict(umap_embed)

# ✅ Step 7: Evaluation
mask = df['HDBSCAN_CatNum_Label_PCA'] != -1
if mask.sum() > 1:
    silhouette = silhouette_score(umap_embed[mask], df.loc[mask, 'HDBSCAN_CatNum_Label_PCA'])
    print("✅ PCA + UMAP + HDBSCAN Silhouette Score:", silhouette)
else:
    print("⚠️ Too much noise – Silhouette not computed")

# ✅ Step 8: Cluster Count
n_clusters = len(np.unique(df['HDBSCAN_CatNum_Label_PCA'])) - (1 if -1 in df['HDBSCAN_CatNum_Label_PCA'] else 0)
print("📊 Number of clusters (excluding noise):", n_clusters)

# ✅ Step 9: Preview
print(df[['HDBSCAN_CatNum_Label_PCA', 'Gender', 'Location_Zone', 'Tenure', 'Loyalty Tier']].head())
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
#pca rsukts 
import pandas as pd

# Step 1: Filter out noise (DO NOT overwrite original df)
df_cleaned_clusters = df[df['HDBSCAN_CatNum_Label_PCA'] != -1].copy()

# Step 2: Group and aggregate cluster profiles
cluster_profiles_summary = df_cleaned_clusters.groupby('HDBSCAN_CatNum_Label_PCA').agg({
    'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
    'Loyalty_Tier_Score': lambda x: x.value_counts(normalize=True).to_dict(),
    'Location_Zone': lambda x: x.value_counts().head(5).to_dict(),
    'Tenure': lambda x: x.value_counts(normalize=True).to_dict(),
})

# Step 3: Optional – Convert to string to avoid truncation
for col in cluster_profiles_summary.columns:
    cluster_profiles_summary[col] = cluster_profiles_summary[col].apply(str)

# Step 4: Set display options to show full width
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Step 5: View
cluster_profiles_summary
# Out:
#                                                                                Gender                                                       Loyalty_Tier_Score                                                                Location_Zone                                                                     Tenure
# HDBSCAN_CatNum_Label_PCA
# 0                         {'Male': 0.5438202247191011, 'Female': 0.45617977528089887}   {1: 0.5056179775280899, 2: 0.27415730337078653, 3: 0.2202247191011236}     {'Central': 134, 'West': 102, 'East': 84, 'North-East': 77, 'North': 48}                                {'Mid-Term': 1.0, 'New': 0.0, 'Loyal': 0.0}
# 1                          {'Female': 0.5257009345794392, 'Male': 0.4742990654205608}  {1: 0.4602803738317757, 2: 0.35046728971962615, 3: 0.18925233644859812}      {'Central': 133, 'East': 91, 'West': 83, 'North-East': 73, 'North': 48}                                {'Loyal': 1.0, 'New': 0.0, 'Mid-Term': 0.0}
# ...

# %%
#current at with diff oridnal score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import silhouette_score
import umap
import hdbscan
import numpy as np
import pandas as pd

# Step 0: Ordinal and Binning
df['Loyalty_Tier_Score'] = df['Loyalty Tier'].map({'Silver': 1, 'Gold': 2, 'Platinum': 3})

df['Tenure'] = pd.cut(
    df['Days_Since_Joined'],
    bins=[0, 300, 700, df['Days_Since_Joined'].max()],
    labels=['New', 'Mid-Term', 'Loyal']
)

# Step 1: One-Hot Encoding
categorical_cols = ['Location_Zone', 'Gender', 'Join_Year', 'Join_Month', 'Join_Quarter', 'Tenure']
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
cat_encoded = encoder.fit_transform(df[categorical_cols])

# Step 2: Scale numerical (loyalty score)
scaler = StandardScaler()
num_scaled = scaler.fit_transform(df[['Loyalty_Tier_Score']])

# Step 3: Combine features
combined_features = np.hstack([cat_encoded, num_scaled])

# Step 4: UMAP
embed = umap.UMAP(
    n_neighbors=150,
    min_dist=0.1,
    n_components=10,
    random_state=42
).fit_transform(combined_features)

# Step 5: HDBSCAN
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=400,
    min_samples=5,
    prediction_data=True
)
df['HDBSCAN_CatNum_Label_1'] = clusterer.fit_predict(embed)

# Step 6: Evaluate
mask = df['HDBSCAN_CatNum_Label_1'] != -1
if mask.sum() > 1:
    silhouette = silhouette_score(embed[mask], df.loc[mask, 'HDBSCAN_CatNum_Label_1'])
    print("✅ Silhouette Score:", silhouette)
else:
    print("⚠️ Too much noise – Silhouette not computed")

# Step 7: Cluster count
n_clusters = len(np.unique(df['HDBSCAN_CatNum_Label_1'])) - (1 if -1 in df['HDBSCAN_CatNum_Label_1'] else 0)
print("📊 Number of clusters (excluding noise):", n_clusters)

# Optional: View sample
print(df[['HDBSCAN_CatNum_Label_1', 'Tenure_Category', 'Gender', 'Location_Zone', 'Loyalty Tier']].head())
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Silhouette Score: 0.7616744
# ...

# %%
import pandas as pd

# Step 1: Filter out noise (DO NOT overwrite original df)
df_cleaned_clusters = df[df['HDBSCAN_CatNum_Label_1'] != -1].copy()

# Step 2: Group and aggregate cluster profiles
cluster_profiles_summary = df_cleaned_clusters.groupby('HDBSCAN_CatNum_Label_1').agg({
    'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
    'Loyalty_Tier_Score': lambda x: x.value_counts(normalize=True).to_dict(),
    'Location_Zone': lambda x: x.value_counts().head(5).to_dict(),
    'Tenure': lambda x: x.value_counts(normalize=True).to_dict(),
})

# Step 3: Optional – Convert to string to avoid truncation
for col in cluster_profiles_summary.columns:
    cluster_profiles_summary[col] = cluster_profiles_summary[col].apply(str)

# Step 4: Set display options to show full width
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Step 5: View
cluster_profiles_summary
# Out:
#                                                                              Gender                                                        Loyalty_Tier_Score                                                                Location_Zone                                                                     Tenure
# HDBSCAN_CatNum_Label_1
# 0                         {'Female': 0.5470085470085471, 'Male': 0.452991452991453}     {1: 0.5363247863247863, 2: 0.2841880341880342, 3: 0.1794871794871795}    {'Central': 122, 'West': 114, 'North-East': 100, 'East': 75, 'North': 57}                                {'New': 1.0, 'Mid-Term': 0.0, 'Loyal': 0.0}
# 1                        {'Male': 0.5347222222222222, 'Female': 0.4652777777777778}  {1: 0.49537037037037035, 2: 0.29398148148148145, 3: 0.21064814814814814}     {'Central': 125, 'West': 106, 'North-East': 80, 'East': 71, 'North': 50}                                {'Mid-Term': 1.0, 'New': 0.0, 'Loyal': 0.0}
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import umap

# Step: 2D UMAP Projection
umap_2d = umap.UMAP(n_components=2, random_state=42).fit_transform(combined_features)
df['UMAP1'] = umap_2d[:, 0]
df['UMAP2'] = umap_2d[:, 1]

# Step: Plot Clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df[df['HDBSCAN_CatNum_Label_1'] != -1],
    x='UMAP1',
    y='UMAP2',
    hue='HDBSCAN_CatNum_Label_1',
    palette='tab20',
    legend='full',
    s=60,
    edgecolor='black',
    linewidth=0.3
)

# Styling
plt.title("📌 UMAP 2D Cluster Visualization", fontsize=16, weight='bold')
plt.xlabel("UMAP Dimension 1", fontsize=12)
plt.ylabel("UMAP Dimension 2", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_892\2411320381.py:30: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Ensure HDBSCAN label is a column
cluster_profiles_summary = cluster_profiles_summary.reset_index()

# Function to get the top value from a dictionary
def get_top_key(d):
    if isinstance(d, dict) and len(d) > 0:
        return max(d.items(), key=lambda x: x[1])[0]
    return 'Unknown'

# Generate cluster label columns
cluster_profiles_summary['Dominant_Gender'] = cluster_profiles_summary['Gender'].apply(get_top_key)
cluster_profiles_summary['Dominant_Loyalty_Tier'] = cluster_profiles_summary['Loyalty_Tier_Score'].apply(
    lambda d: {1: 'Silver', 2: 'Gold', 3: 'Platinum'}.get(get_top_key(d), 'Unknown')
)
cluster_profiles_summary['Dominant_Location'] = cluster_profiles_summary['Location'].apply(get_top_key)
cluster_profiles_summary['Dominant_Tenure'] = cluster_profiles_summary['Tenure'].apply(get_top_key)

# Compose human-readable cluster labels
cluster_profiles_summary['Cluster_Label'] = (
    cluster_profiles_summary['Dominant_Tenure'] + ' ' +
    cluster_profiles_summary['Dominant_Gender'] + 's from ' +
    cluster_profiles_summary['Dominant_Location'] + ' (' +
    cluster_profiles_summary['Dominant_Loyalty_Tier'] + ' Tier)'
)

# View labeled clusters
cluster_profiles_summary[['HDBSCAN_CatNum_Label_1', 'Cluster_Label']]
# Out:
#    HDBSCAN_CatNum_Label_1                                      Cluster_Label
# 0                       0     Mid-Term Males from Central Area (Silver Tier)
# 1                       1         New Males from Choa Chu Kang (Silver Tier)
# 2                       2        Loyal Females from Queenstown (Silver Tier)
# 3                       3          Mid-Term Males from Hougang (Silver Tier)
# 4                       4         New Females from Bukit Batok (Silver Tier)
# 5                       5         Loyal Females from Sembawang (Silver Tier)
# 6                       6             Loyal Females from Bedok (Silver Tier)
# 7                       7  Mid-Term Females from Choa Chu Kang (Silver Tier)
# 8                       8    Mid-Term Females from Bukit Timah (Silver Tier)

# %%
print(sorted(df['HDBSCAN_CatNum_Label_1'].unique()))
print(df_clean['HDBSCAN_CatNum_Label_1'].value_counts())
# Out:
# [-1, 0, 1, 2, 3, 4, 5, 6, 7, 8]
# HDBSCAN_CatNum_Label_1
# 8    783
# 5    736
# 2    449
# 0    445
# 7    443
# 3    432
# 6    428
# 1    419
# 4    401
# Name: count, dtype: int64

# %%
import umap
import matplotlib.pyplot as plt
import seaborn as sns

# Recreate UMAP 2D projection using categorical + numerical combined features
umap_2d = umap.UMAP(n_components=2, random_state=42).fit_transform(combined_features)
df['UMAP1'] = umap_2d[:, 0]
df['UMAP2'] = umap_2d[:, 1]

# 1. 📌 UMAP 2D Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df[df['HDBSCAN_CatNum_Label_1'] != -1], x='UMAP1', y='UMAP2',
                hue='HDBSCAN_CatNum_Label_1', palette='tab20', legend='full', s=50)
plt.title("📌 UMAP 2D Cluster Visualization ")
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_60180\2717289666.py:16: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import umap
import matplotlib.pyplot as plt
import seaborn as sns

# Recompute UMAP 2D projection (optional if already done)
umap_2d = umap.UMAP(n_components=2, random_state=42).fit_transform(combined_features)

# Assign UMAP coordinates
df['UMAP1'] = umap_2d[:, 0]
df['UMAP2'] = umap_2d[:, 1]

# Filter non-noise
df_vis = df[df['HDBSCAN_CatNum_Label_1'] != -1]

# Plot
plt.figure(figsize=(12, 7))
sns.scatterplot(
    data=df_vis,
    x='UMAP1',
    y='UMAP2',
    hue='HDBSCAN_CatNum_Label_1',
    palette='tab10',
    s=70,
    alpha=0.85,
    edgecolor='black',
    linewidth=0.3
)
plt.title("📌 UMAP 2D Cluster Visualization (Cat + Ordinal + HDBSCAN)", fontsize=14)
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Cluster', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_60180\3502549270.py:33: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_60180\3418332406.py:28: UserWarning: Glyph 129513 (\N{JIGSAW PUZZLE PIECE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129513 (\N{JIGSAW PUZZLE PIECE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Loop through each cluster and print sample rows
unique_clusters = df['HDBSCAN_CatNum_Label'].unique()
unique_clusters = [c for c in unique_clusters if c != -1]  # exclude noise if needed

for cluster in sorted(unique_clusters):
    print(f"\n🧩 Cluster {cluster} — Sample Records:")
    display(df[df['HDBSCAN_CatNum_Label'] == cluster].head(3)[[
        'Location_Zone', 'Gender', 'Loyalty Tier', 'Days_Since_Joined', 'Is_New'
    ]])
# Out:
# 🧩 Cluster 0 — Sample Records:
#    Location_Zone Gender Loyalty Tier  Days_Since_Joined  Is_New
# 15       Central   Male     Platinum               1070       0
# 17         North   Male       Silver               1086       0
# 32       Central   Male       Silver               1087       0
# 🧩 Cluster 1 — Sample Records:
#    Location_Zone  Gender Loyalty Tier  Days_Since_Joined  Is_New
# 28    North-East  Female       Silver                225       0
# 30       Central    Male       Silver                150       1
# 37          East    Male     Platinum                142       1
# 🧩 Cluster 2 — Sample Records:
#    Location_Zone  Gender Loyalty Tier  Days_Since_Joined  Is_New
# 7           East  Female       Silver                978       0
# 18          East    Male     Platinum               1008       0
# 45       Central    Male       Silver                967       0
# 🧩 Cluster 3 — Sample Records:
#   Location_Zone  Gender Loyalty Tier  Days_Since_Joined  Is_New
# ...

# %%
# Step 1: Confirm label column exists
assert 'HDBSCAN_CatNum_Label' in df.columns, "HDBSCAN_CatNum_Label column missing"

# Step 2: Filter noise clusters
df_clean = df[df['HDBSCAN_CatNum_Label'] != -1]

# Step 3: Cluster profiling
cluster_profiles = df_clean.groupby('HDBSCAN_CatNum_Label').agg({
    'Days_Since_Joined': ['mean', 'min', 'max'],
    'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
    'Loyalty Tier': lambda x: x.value_counts(normalize=True).to_dict(),
    'Location_Zone': lambda x: x.value_counts().head(3).to_dict(),
    'Is_New': 'mean'
})

# Step 4: Flatten MultiIndex columns
cluster_profiles.columns = ['_'.join(col).strip() for col in cluster_profiles.columns.values]
cluster_profiles.reset_index(inplace=True)

# Step 5: Save to CSV
output_path = "cluster_profiles_HDBSCAN_CatNum_Label.csv"
cluster_profiles.to_csv(output_path, index=False)

print("✅ Cluster profiling saved to:", output_path)
# Out:
# ✅ Cluster profiling saved to: cluster_profiles_HDBSCAN_CatNum_Label.csv

# %%
#PCAAAA

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
import umap
import hdbscan
import numpy as np
from sklearn.metrics import silhouette_score

# Step 0: Define columns
categorical_cols = [
    'Location_Zone', 'Gender', 'Loyalty Tier',
    'Join_Year', 'Join_Month', 'Join_Quarter', 'Is_New'
]
numerical_cols = ['Days_Since_Joined']


# Step 1: Encode categorical
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
cat_encoded = encoder.fit_transform(df[categorical_cols])

# Step 2: Scale numerical
scaler = StandardScaler()
num_scaled = scaler.fit_transform(df[numerical_cols])

# Step 3: Combine features
combined_features_pca = np.hstack([cat_encoded, num_scaled])

# ✅ Step 4: PCA before UMAP
pca = PCA(n_components=0.95, random_state=42)
pca_features = pca.fit_transform(combined_features_pca)

# ✅ Step 5: UMAP on PCA-reduced features
umap_embed_pca = umap.UMAP(
    n_neighbors=70,
    min_dist=0.1,
    n_components=10,
    random_state=42
).fit_transform(pca_features)

# Step 6: HDBSCAN on PCA-UMAP features
clusterer_pca = hdbscan.HDBSCAN(
    min_cluster_size=150,
    min_samples=15,
    prediction_data=True
)
df['HDBSCAN_CatNum_Label_PCA'] = clusterer_pca.fit_predict(umap_embed_pca)

# Step 7: Evaluation
mask_pca = df['HDBSCAN_CatNum_Label_PCA'] != -1
if mask_pca.sum() > 1:
    silhouette_pca = silhouette_score(umap_embed_pca[mask_pca], df.loc[mask_pca, 'HDBSCAN_CatNum_Label_PCA'])
    print("✅ PCA + UMAP + HDBSCAN Silhouette Score:", silhouette_pca)
else:
    print("⚠️ Too much noise – Silhouette Score not computed")

# Step 8: Cluster count
n_clusters_pca = len(np.unique(df['HDBSCAN_CatNum_Label_PCA'])) - (1 if -1 in df['HDBSCAN_CatNum_Label_PCA'] else 0)
print(f"📊 Number of clusters (excluding noise): {n_clusters_pca}")

# Preview labels
print(df[['HDBSCAN_CatNum_Label_PCA']].head())
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
# Step 1: Filter out noise for PCA-based clusters
df_clean_pca = df[df['HDBSCAN_CatNum_Label_PCA'] != -1]

# Step 2: Group and aggregate for profiling
cluster_profiles_pca = df_clean_pca.groupby('HDBSCAN_CatNum_Label_PCA').agg({
    'Days_Since_Joined': ['mean', 'min', 'max'],
    'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
    'Loyalty Tier': lambda x: x.value_counts(normalize=True).to_dict(),
    'Location_Zone': lambda x: x.value_counts().head(3).to_dict(),
    'Is_New': 'mean'
})

# Step 3: Flatten column names
cluster_profiles_pca.columns = ['_'.join(col).strip() for col in cluster_profiles_pca.columns.values]
cluster_profiles_pca.reset_index(inplace=True)

# Step 4: Preview
output_path = "cluster_profiles_HDBSCAN_CatNum_Label_PCA.csv"
cluster_profiles_pca.to_csv(output_path, index=False)

# %%
print(df.columns)
# Out:
# Index(['Customer ID', 'Full Name', 'Email Address', 'Phone Number',
#        'Date Joined', 'Location', 'Gender', 'Loyalty Tier', 'Notes',
#        'Location_Zone', 'Days_Since_Joined', 'Join_Year', 'Join_Month',
#        'Join_Quarter', 'Is_New', 'HDBSCAN_CatNum_Label', 'UMAP1', 'UMAP2',
#        'HDBSCAN_Cat_Label', 'HDBSCAN_CatNum_Label_PCA'],
#       dtype='object')

# %%
# Step 1: Filter out noise for PCA-based clusters
df_clean_pca = df[df['HDBSCAN_CatNum_Label_PCA'] != -1]

# Step 2: Group and aggregate for profiling
cluster_profiles_pca = df_clean_pca.groupby('HDBSCAN_CatNum_Label_PCA').agg({
    'Days_Since_Joined': ['mean', 'min', 'max'],
    'Gender': lambda x: x.value_counts(normalize=True).to_dict(),
    'Loyalty_Tier_Score: lambda x: x.value_counts(normalize=True).to_dict(),
    'Location_Zone': lambda x: x.value_counts().head(3).to_dict(),
    'Is_New': 'mean'
})

# Step 3: Flatten column names
cluster_profiles_pca.columns = ['_'.join(col).strip() for col in cluster_profiles_pca.columns.values]
cluster_profiles_pca.reset_index(inplace=True)

# Step 4: Preview
cluster_profiles_pca
# Out:
#   Cell In[41], line 8
#     'Loyalty_Tier_Score: lambda x: x.value_counts(normalize=True).to_dict(),
#     ^
# SyntaxError: unterminated string literal (detected at line 8)

# %%
# Out:
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Lenovo\Downloads\Year 3 Major project\marketing-portal\.venv\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
# Out:
#     HDBSCAN_CatNum_Label_PCA  Days_Since_Joined_mean  Days_Since_Joined_min  \
# 0                          0               85.756410                     34
# 1                          1              825.796729                    781
# 2                          2              458.813483                    415
# 3                          3              185.766110                    140
# 4                          4              554.398148                    507
# 5                          5             1092.477011                   1055
# 6                          6              276.224868                    232
# 7                          7              367.805897                    324
# 8                          8              643.392593                    598
# 9                          9              736.599057                    690
# 10                        10             1008.699332                    963
# ...
